# %% [markdown]
# # BANK ACCOUNT MANAGEMENT SYSTEM

# %% [markdown]
# ![Bank Account Management Dashboard.png](attachment:7baa7804-2f64-481b-a9a3-45930d8d2021.png)

# %%
import json
from datetime import datetime

try:
    with open("bank.json", "r") as file:
        bank = json.load(file)

except FileNotFoundError:
    bank = []

print(bank)
# Out:
# [{'account_number': 1001, 'name': 'Shriya Verma', 'balance': 50000.0, 'transactions': []}, {'account_number': 1002, 'name': 'Nancy Tyagi', 'balance': 60000.0, 'transactions': []}, {'account_number': 1003, 'name': 'Mohit Sharma', 'balance': 70000.0, 'transactions': []}, {'account_number': 1004, 'name': 'Virat Kohli', 'balance': 100000.0, 'transactions': []}, {'account_number': 1005, 'name': 'Sanjay Shukla', 'balance': 157363.45, 'transactions': []}, {'account_number': 1006, 'name': 'Shalini Verma', 'balance': 76573.9, 'transactions': []}, {'account_number': 1007, 'name': 'Sneha Sharma', 'balance': 76000.0, 'transactions': []}, {'account_number': 1008, 'name': 'Anjali Singh', 'balance': 56983.7, 'transactions': []}, {'account_number': 1009, 'name': 'Tanya Malhotra', 'balance': 78453.65, 'transactions': []}, {'account_number': 1010, 'name': 'Faiz Khan', 'balance': 85434.76, 'transactions': []}]

# %%
def save_records(): 
    with open("bank.json", "w") as file:
        json.dump(bank,file,indent = 4)

# %%
def create_account():
    account_number = int(input("Enter account number: "))

    for account in bank:
        if account["account_number"] == account_number:
            print("Account number already exists!")
            return

    name = input("Enter account holder's name: ")
    balance = float(input("Enter initial deposit: "))

    account = {
        "account_number": account_number,
        "name": name,
        "balance": balance,
        "transactions": []
    }

    bank.append(account)
    save_records()

    print("Account created successfully!")

# %%
create_account()
# Out:
# Enter account number : 1001
# Enter account holder's name: Shriya Verma
# Enter intitial deposit : 50000
# Account created successfully !

# %%
create_account()
# Out:
# Enter account number : 1002
# Enter account holder's name: Nancy Tyagi
# Enter intitial deposit : 60000
# Account created successfully !

# %%
create_account()
# Out:
# Enter account number : 1003
# Enter account holder's name: Mohit Sharma
# Enter intitial deposit : 70000
# Account created successfully !

# %%
create_account()
# Out:
# Enter account number : 1004
# Enter account holder's name: Virat Kohli
# Enter intitial deposit : 100000
# Account created successfully !

# %%
create_account()
# Out:
# Enter account number : 1005
# Enter account holder's name: Sanjay Shukla
# Enter intitial deposit : 157363.45
# Account created successfully !

# %%
create_account()
# Out:
# Enter account number : 1006
# Enter account holder's name: Shalini Verma
# Enter intitial deposit : 76573.90
# Account created successfully !

# %%
create_account()
# Out:
# Enter account number : 1007
# Enter account holder's name: Sneha Sharma
# Enter intitial deposit : 76000
# Account created successfully !

# %%
create_account()
# Out:
# Enter account number : 1008
# Enter account holder's name: Anjali Singh
# Enter intitial deposit : 56983.70
# Account created successfully !

# %%
create_account()
# Out:
# Enter account number : 1009
# Enter account holder's name: Tanya Malhotra
# Enter intitial deposit : 78453.65
# Account created successfully !

# %%
create_account()
# Out:
# Enter account number : 1010
# Enter account holder's name: Faiz Khan
# Enter intitial deposit : 85434.76
# Account created successfully !

# %%
print(bank)
# Out:
# [{'account_number': 1001, 'name': 'Shriya Verma', 'balance': 50000.0, 'transactions': []}, {'account_number': 1002, 'name': 'Nancy Tyagi', 'balance': 60000.0, 'transactions': []}, {'account_number': 1003, 'name': 'Mohit Sharma', 'balance': 70000.0, 'transactions': []}, {'account_number': 1004, 'name': 'Virat Kohli', 'balance': 100000.0, 'transactions': []}, {'account_number': 1005, 'name': 'Sanjay Shukla', 'balance': 157363.45, 'transactions': []}, {'account_number': 1006, 'name': 'Shalini Verma', 'balance': 76573.9, 'transactions': []}, {'account_number': 1007, 'name': 'Sneha Sharma', 'balance': 76000.0, 'transactions': []}, {'account_number': 1008, 'name': 'Anjali Singh', 'balance': 56983.7, 'transactions': []}, {'account_number': 1009, 'name': 'Tanya Malhotra', 'balance': 78453.65, 'transactions': []}, {'account_number': 1010, 'name': 'Faiz Khan', 'balance': 85434.76, 'transactions': []}]

# %%
def deposit_money():
    account_number = int(input("Enter account number: "))
    amount = float(input("Enter deposit amount: "))

    for account in bank:
        if account["account_number"] == account_number:
            account["balance"] += amount

            transaction = {
                "type": "Deposit",
                "amount": amount,
                "date": str(datetime.now())
            }

            account["transactions"].append(transaction)

            save_records()

            print("Money deposited successfully!")
            print("Current balance:", account["balance"])
            return

    print("Account not found!")

# %%
deposit_money()
# Out:
# Enter account number:  1001
# Enter deposit amount:  56000
# Money deposited successfully!
# Current balance: 106000.0

# %%
deposit_money()
# Out:
# Enter account number:  1005
# Enter deposit amount:  76000
# Money deposited successfully!
# Current balance: 233363.45

# %%
deposit_money()
# Out:
# Enter account number:  1001
# Enter deposit amount:  200000
# Money deposited successfully!
# Current balance: 306000.0

# %%
print(bank)
# Out:
# [{'account_number': 1001, 'name': 'Shriya Verma', 'balance': 306000.0, 'transactions': [{'type': 'Deposit', 'amount': 56000.0, 'date': '2026-09-26 00:39:35.609867'}, {'type': 'Deposit', 'amount': 200000.0, 'date': '2026-09-26 00:40:24.307152'}]}, {'account_number': 1002, 'name': 'Nancy Tyagi', 'balance': 60000.0, 'transactions': []}, {'account_number': 1003, 'name': 'Mohit Sharma', 'balance': 70000.0, 'transactions': []}, {'account_number': 1004, 'name': 'Virat Kohli', 'balance': 100000.0, 'transactions': []}, {'account_number': 1005, 'name': 'Sanjay Shukla', 'balance': 233363.45, 'transactions': [{'type': 'Deposit', 'amount': 76000.0, 'date': '2026-09-26 00:40:09.932670'}]}, {'account_number': 1006, 'name': 'Shalini Verma', 'balance': 76573.9, 'transactions': []}, {'account_number': 1007, 'name': 'Sneha Sharma', 'balance': 76000.0, 'transactions': []}, {'account_number': 1008, 'name': 'Anjali Singh', 'balance': 56983.7, 'transactions': []}, {'account_number': 1009, 'name': 'Tanya Malhotra', 'balance': 78453.65, 'transactions': []}, {'account_number': 1010, 'name': 'Faiz Khan', 'balance': 85434.76, 'transactions': []}]

# %%
def withdraw_money():
    account_number = int(input("Enter account number: "))
    amount = float(input("Enter withdrawal amount: "))

    for account in bank:
        if account["account_number"] == account_number:
            
            if amount > account["balance"]:
                print("Insufficient balance!")
                return

            account["balance"] -= amount

            transaction = {
                "type": "Withdrawal",
                "amount": amount,
                "date": str(datetime.now())
            }

            account["transactions"].append(transaction)

            save_records()

            print("Money withdrawn successfully!")
            print("Current balance:", account["balance"])
            return

    print("Account not found!")

# %%
withdraw_money()
# Out:
# Enter account number:  1002
# Enter withdrawal amount:  5000
# Money withdrawn successfully!
# Current balance: 55000.0

# %%
withdraw_money()
# Out:
# Enter account number:  1010
# Enter withdrawal amount:  7054
# Money withdrawn successfully!
# Current balance: 78380.76

# %%
withdraw_money()
# Out:
# Enter account number:  1009
# Enter withdrawal amount:  100000
# Insufficient balance!

# %%
def check_balance():
    account_number = int(input("Enter account number: "))

    for account in bank:
        if account["account_number"] == account_number:
            print("Account holder:", account["name"])
            print("Current balance:", account["balance"])
            return

    print("Account not found!")

# %%
check_balance()
# Out:
# Enter account number:  1001
# Account holder: Shriya Verma
# Current balance: 306000.0

# %%
check_balance()
# Out:
# Enter account number:  112
# Account not found!

# %%
check_balance()
# Out:
# Enter account number:  1010
# Account holder: Faiz Khan
# Current balance: 78380.76

# %%
check_balance()
# Out:
# Enter account number:  1132
# Account not found!

# %%
def transaction_history():
    account_number = int(input("Enter account number: "))

    for account in bank:
        if account["account_number"] == account_number:

            print("Transaction History")
            
            if len(account["transactions"]) == 0:
                print("No transactions found!")
                return

            for transaction in account["transactions"]:
                print("Type:", transaction["type"])
                print("Amount:", transaction["amount"])
                print("Date:", transaction["date"])
                print("--------------------")

            return

    print("Account not found!")

# %%
transaction_history()
# Out:
# Enter account number:  1004
# Transaction History
# No transactions found!

# %%
transaction_history()
# Out:
# Enter account number:  1001
# Transaction History
# Type: Deposit
# Amount: 56000.0
# Date: 2026-09-26 00:39:35.609867
# --------------------
# Type: Deposit
# Amount: 200000.0
# Date: 2026-09-26 00:40:24.307152
# --------------------

# %%
transaction_history()
# Out:
# Enter account number:  1010
# Transaction History
# Type: Withdrawal
# Amount: 7054.0
# Date: 2026-09-26 00:44:54.592437
# --------------------

# %%
transaction_history()
# Out:
# Enter account number:  1111
# Account not found!

# %%
def main_menu():
    while True:
        print("\n===== BANK ACCOUNT MANAGEMENT SYSTEM =====")
        print("1. Create Account")
        print("2. Deposit Money")
        print("3. Withdraw Money")
        print("4. Check Balance")
        print("5. Transaction History")
        print("6. Exit")

        choice = input("Enter your choice: ")

        if choice == "1":
            create_account()

        elif choice == "2":
            deposit_money()

        elif choice == "3":
            withdraw_money()

        elif choice == "4":
            check_balance()

        elif choice == "5":
            transaction_history()

        elif choice == "6":
            print("Thank you for using the Bank Account Management System!")
            break

        else:
            print("Invalid choice! Please try again.")

# %%
main_menu()
# Out:
# ===== BANK ACCOUNT MANAGEMENT SYSTEM =====
# 1. Create Account
# 2. Deposit Money
# 3. Withdraw Money
# 4. Check Balance
# 5. Transaction History
# 6. Exit
# Enter your choice:  1
# Enter account number:  1011
# Enter account holder's name:  Indresh Pandit
# Enter initial deposit:  90000
# Account created successfully!
#
# ===== BANK ACCOUNT MANAGEMENT SYSTEM =====
# 1. Create Account
# 2. Deposit Money
# 3. Withdraw Money
# 4. Check Balance
# 5. Transaction History
# 6. Exit
# Enter your choice:  2
# Enter account number:  1006
# Enter deposit amount:  543267
# Money deposited successfully!
# Current balance: 619840.9
#
# ===== BANK ACCOUNT MANAGEMENT SYSTEM =====
# 1. Create Account
# 2. Deposit Money
# 3. Withdraw Money
# 4. Check Balance
# 5. Transaction History
# 6. Exit
# Enter your choice:  3
# Enter account number:  1008
# Enter withdrawal amount:  37668
# Money withdrawn successfully!
# Current balance: 19315.699999999997
#
# ===== BANK ACCOUNT MANAGEMENT SYSTEM =====
# 1. Create Account
# 2. Deposit Money
# 3. Withdraw Money
# 4. Check Balance
# 5. Transaction History
# 6. Exit
# Enter your choice:  4
# Enter account number:  1011
# Account holder: Indresh Pandit
# Current balance: 90000.0
#
# ===== BANK ACCOUNT MANAGEMENT SYSTEM =====
# 1. Create Account
# 2. Deposit Money
# 3. Withdraw Money
# 4. Check Balance
# 5. Transaction History
# 6. Exit
# Enter your choice:  5
# Enter account number:  1001
# Transaction History
# Type: Deposit
# Amount: 56000.0
# Date: 2026-09-26 00:39:35.609867
# --------------------
# Type: Deposit
# Amount: 200000.0
# Date: 2026-09-26 00:40:24.307152
# --------------------
#
# ===== BANK ACCOUNT MANAGEMENT SYSTEM =====
# 1. Create Account
# 2. Deposit Money
# 3. Withdraw Money
# 4. Check Balance
# 5. Transaction History
# 6. Exit
# Enter your choice:  6
# Thank you for using the Bank Account Management System!
